# %% [markdown]
# <a href="https://colab.research.google.com/github/itzBhishan/EDA/blob/main/Global_Terrorism_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Project Name**    - Exploratory Data Analysis- Terrorism

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Student Name -** Bhishan Bhurse

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
# Explore and analyze the data to discover key findings pertaining to terrorist activities.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/itzBhishan/EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# As a security/defence analyst, try to find out the hot zone of terrorism. What all security issues and insights you can derive by EDA?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Forbid Terrorist Activities

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np     #NumPy can be used to perform a wide variety of mathematical operations on arrays.
import pandas as pd    # allowing us to access many of matplotlib's and NumPy's methods with less code
import seaborn as sns  #Seaborn is a library for making statistical graphics in Python.
import matplotlib.pyplot as plt  #comprehensive library for creating static, animated, and interactive visualizations in Python
import plotly.express as px       #plotly enables Python users to create beautiful interactive web-based visualizations

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/AlmaBetter/project/EDA/Global Terrorism Data.csv",encoding="ISO-8859-1")
# Out:
# <ipython-input-3-31feb857bb4c>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("/content/drive/MyDrive/AlmaBetter/project/EDA/Global Terrorism Data.csv",encoding="ISO-8859-1")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
data.sample()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 113576  201301110011   2013       1    11        NaN         0        NaN
#
#         country country_txt  region  ... addnotes  \
# 113576       78      Greece       8  ...      NaN
#
#                                                    scite1  \
# 113576  "Petrol bombs thrown at home of Greek governme...
#
#                                                    scite2  \
# 113576  "'Several Thousand' Greeks Protest in Athens A...
#
#                                                    scite3  \
# 113576  "Greek gov't spokesman condemns latest petrol ...
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 113576  START Primary Collection       -9        -9        0      -9
#
#                                          related
# 113576  201301110011, 201301110012, 201301110013
#
# [1 rows x 135 columns]

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (181691, 135)

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info
# Out:
# <bound method DataFrame.info of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(data[data.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# gsubname3           181671
# weapsubtype4_txt    181621
# weapsubtype4        181621
# weaptype4           181618
# weaptype4_txt       181618
#                      ...
# suicide                  0
# success                  0
# crit3                    0
# property                 0
# eventid                  0
# Length: 135, dtype: int64

# %%
# Visualizing the missing values

#Checking Null value by plotting Heatmap

sns.heatmap(data.isnull(),cbar=True)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  The given dataset is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.The goal is to understand and take steps to control further spread of terrorism and establish peace.
#
# 1.   There are 181691 rows x 135 columns in our dataset.
# 2.   The Data contains a total of 135 columns, which are both numeric and text.
# 3.   Our dataset has some missing values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe
data.describe(include="all")
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1.   provstate=state
# 2.   region_txt=Region Name
#
# 1.   attacktype1_txt= Mean of Attack
# 2.  target1=Targets Of Terrorist Attacks
#
# 1.   nkill= Total number of Killed people
# 2.  nwound= Total Number of Wounded People
#
# 1.  gname= Name of Organization Behind Terrorist Activities
# 2.targtype1_txt=Target_type
#
# 1.  weaptype1_txt= Type of Weapons Used In Attack
# 2.   iyear=Year of Incident Happened
#
# 1.   imonth=Month of Year
# 2.   country_txt=Name of Country

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in data.columns.tolist():
  print("No. of Unique values in ",i,"is",data[i].unique(),",")
# Out:
# No. of Unique values in  eventid is [197000000001 197000000002 197001000001 ... 201712310030 201712310031
#  201712310032] ,
# No. of Unique values in  iyear is [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1986 1982
#  1983 1984 1985 1987 1988 1989 1990 1991 1992 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017] ,
# No. of Unique values in  imonth is [ 7  0  1  2  3  4  5  6  8  9 10 11 12] ,
# No. of Unique values in  iday is [ 2  0  1  3  6  8  9 10 11 12 13 14 15 19 20 21 22 25 26 27 28 30 31  4
#   7 16 17 18 23 24  5 29] ,
# No. of Unique values in  approxdate is [nan 'January 19-20, 1970' 'February 6-9, 1970' ... '2017-12-29 00:00:00'
#  'December 25, 2017-January 5, 2018' '2017-12-31 00:00:00'] ,
# No. of Unique values in  extended is [0 1] ,
# No. of Unique values in  resolution is [nan '3/8/1970' '3/15/1970' ... '3/23/2013' '12/9/2011' '12/27/2011'] ,
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#put variables in List format
data.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
#Rename variables that are to be consider for analysis
data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day', 'country_txt':'Country','provstate':'state',
                         'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type'},inplace=True)
data.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Consider only those variables in dataset which are to be taken for further analysis
df = data[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
                      'Wounded','Target','Group','Target_type','Weapon_type']]
df.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target  \
# ...

# %%
df.shape
# Out:
# (181691, 16)

# %%
#where exactly missing values are?
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# Wounded        16311
# Killed         10313
# longitude       4557
# latitude        4556
# Target           636
# city             434
# state            421
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# AttackType         0
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %% [markdown]
# Data shows that there are missing values in variables like state,city,latitude,longitude,killed,Wounded,Target

# %% [markdown]
#  Firstly  drop missing values of variables state,city,latitude,longitude,Target

# %%
#use drop.na method
print(df.shape)
df.dropna(subset=['state','city','latitude','longitude','Target'],axis=0,inplace=True)
#inplace=True modifies the data frame
df.isnull().sum()
# Out:
# (181691, 16)
# <ipython-input-26-167c6386e737>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['state','city','latitude','longitude','Target'],axis=0,inplace=True)
# Year               0
# Month              0
# Day                0
# Country            0
# state              0
# Region             0
# city               0
# latitude           0
# longitude          0
# AttackType         0
# Killed          9721
# Wounded        15591
# Target             0
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %% [markdown]
# Then Replace missing values with the average of that column for variables like Killed ,Wounded

# %%
meank=df['Killed'].mean()
meanw=df['Wounded'].mean()

#Replacing NaN values with mean of the data(updating as well)
df['Killed']=df['Killed'].replace(np.nan,meank)

df['Wounded']=df['Wounded'].replace(np.nan,meanw)
# Out:
# <ipython-input-30-00437dc88da5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Killed']=df['Killed'].replace(np.nan,meank)
# <ipython-input-30-00437dc88da5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wounded']=df['Wounded'].replace(np.nan,meanw)

# %%
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# state          0
# Region         0
# city           0
# latitude       0
# longitude      0
# AttackType     0
# Killed         0
# Wounded        0
# Target         0
# Group          0
# Target_type    0
# Weapon_type    0
# dtype: int64

# %%
df.shape
# Out:
# (175708, 16)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Initially for better understanding of terminologies I rename variables that are to be consider for analysis .Then consider only those variables in dataset which are to be taken for further analysis.Thus I curved out dataframe of shape (181691, 16).  Data shows that there are missing values in variables like state,city,latitude,longitude,killed,Wounded,Target so I Firstly drop missing values of variables state,city,latitude,longitude,Target and then replace missing values with the average of that column for variables like Killed ,Wounded.Now there are no missing values in our dataset.And we are ready to analyse data with interesting  plot vizualizations .Now there are no NaN values and we obtained dataframe of shape (175708, 16)

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# Terrorist Activities by Region in each Year

# %%
# Chart - 1 visualization code
pd.crosstab(df.Year, data.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# An area plot displays quantitative data visually.And hepled me analysing Terrorist Activities by Region in each Year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insigts I found in above chart are-
#
#
#
# 1.  Terrorist activities have been increased rapidly since 2010 around the globe
# 2.   Middle East and North Africa witness major attacks throughout the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact of Insights= Data analysis will helped in better placement of peacekeeping forces.
# Negative Impact of Insights =Data analysis can discourage business activities in affected regions

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# Number Of Terrorist Activities Each Year

# %%
# Chart - 2 visualization code
plt.subplots(figsize=(15,6))
sns.countplot(x='Year',data=df,palette='RdYlGn_r',edgecolor=sns.color_palette("YlOrBr", 10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Subplots method provides a way to plot multiple plots on a single figure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Attacks were more during 2014 and then in 2015. When compared to attacks from 1970 onwards, the last 6 years scored a maximum. But from 2014 onwards count started decreasing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above data analysis will definitely boost enthusiasm as terrorist activities are decreasing

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# Number of Attacks By Region

# %%
# Chart - 3 visualization code

plt.figure(figsize=(28, 5))
plt.rcParams.update({'font.size': 10})
plt.xticks(rotation=0)
plt.title('Attacks by Region')

# Create a countplot with the 'Region' column of the DataFrame
sns.countplot(x=df.Region, order=df.Region.value_counts().index)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is a suitable choice for visualizing the distribution of categorical data, such as the number of terrorist attacks by region. It shows the frequency of each region in a bar chart

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Middle East, North Africa and South Asia have abundant human capital which can be further explore for better bussiness perspective.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# which country has faced highest number of attacks

# %%
# Chart - 4 visualization code
df.Country.value_counts()
# Out:
# Iraq             24429
# Pakistan         14287
# Afghanistan      12487
# India            11761
# Colombia          7819
#                  ...
# South Yemen          1
# North Korea          1
# Vanuatu              1
# South Vietnam        1
# St. Lucia            1
# Name: Country, Length: 204, dtype: int64

# %%
#which country has faced highest number of attacks
plt.figure(figsize=(40,5));
plt.rcParams.update({'font.size':8});
plt.xticks(rotation = 90)
plt.title('Attacks by Country')
sns.countplot(x=df.Country)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is a concise and effective way to visualize the distribution of attacks by country

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Government should increase safety measures in these countries

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# which city has faced highest number of attacks

# %%
# Chart - 5 visualization code
df['city'].value_counts()
# Out:
# Baghdad                  7566
# Unknown                  7457
# Karachi                  2644
# Lima                     2339
# Mosul                    2262
#                          ...
# Sangin District             1
# Dmenisi                     1
# Chiang Rai (Province)       1
# Garmabak                    1
# Kubentog                    1
# Name: city, Length: 34886, dtype: int64

# %%
attack_cities = df.city.value_counts()[0:15]
attack_cities
# Out:
# Baghdad         7566
# Unknown         7457
# Karachi         2644
# Lima            2339
# Mosul           2262
# Belfast         2165
# Santiago        1618
# Mogadishu       1578
# San Salvador    1537
# Istanbul        1044
# Athens          1017
# Bogota           978
# Kirkuk           923
# Beirut           903
# Medellin         845
# Name: city, dtype: int64

# %%
# which city faced highest number of attacks
plt.subplots(figsize=(12,6))
sns.barplot(attack_cities.index,attack_cities.values,palette="mako")
plt.title('Top Countries Affected')
plt.xlabel('Cities')
plt.ylabel('Number of attacks')
plt.xticks(rotation= 45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is a plot that presents categorical data with rectangular bars with lengths proportional to the values that they represent. A bar plot shows comparisons among discrete categories. One axis of the plot shows the specific categories being compared, and the other axis represents a measured value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above data analysis shows that Baghdad city is most affected by terrorism.The Baghdad city is followed by Karachi and Lima with regard to curse of terrorism

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Culturally important cities like Baghdad and Karachi has huge unexplored potential that can be used for inclusive development of city

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# which terrorist group has caused the highest damage.

# %%
# Chart - 6 visualization code
df.Group.value_counts()
# Out:
# Unknown                                                                80721
# Taliban                                                                 7374
# Islamic State of Iraq and the Levant (ISIL)                             5584
# Shining Path (SL)                                                       4283
# Al-Shabaab                                                              3273
#                                                                        ...
# Human Rights Renewal Movement (Renovacion por los Derechos Humanos)        1
# El Movimiento Revolucionario Independinista                                1
# Guadalcanal Liberation Army                                                1
# Fatherland                                                                 1
# War Veterans                                                               1
# Name: Group, Length: 3431, dtype: int64

# %%
df['Group'].value_counts()[0:1]
# Out:
# Unknown    80721
# Name: Group, dtype: int64

# %% [markdown]
# Here we can see that unknown group/groups has/have caused the highest damage. There can be indivisuals, small unorganized group, separatist etc under this "unknow group" umbrella or known groups but didn't claim the attack.

# %%
# which terrorist group caused the highest damage
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.countplot(x='Group', data=df, palette='inferno', order=df['Group'].value_counts()[1:16].index)
_ = plt.xlabel('Terrorist group name')
_ = plt.setp(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is a plot that presents categorical data with rectangular bars with lengths proportional to the values that they represent. A bar plot shows comparisons among discrete categories. One axis of the plot shows the specific categories being compared, and the other axis represents a measured value.
# It hepled is finding most injurious terrorist organizations which claimed large number of casualties and deaths.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see the top 15 terrerist groups excluding the highest unknown.From above analysis it is proven that Taliban is most vicious terrorist organization which claimed around 7500 terrorist attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Shortlisting of deadliest terrorist organizations will be helppful in tracing  activites of them .such vigilance will eventually control there malicious acts.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# Weapon which is used most

# %%
# Chart - 7 visualization code
df['Weapon_type'].value_counts()
# Out:
# Explosives                                                                     90414
# Firearms                                                                       56015
# Unknown                                                                        14149
# Incendiary                                                                     10867
# Melee                                                                           3518
# Chemical                                                                         293
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      135
# Sabotage Equipment                                                               128
# Other                                                                            114
# Biological                                                                        33
# Fake Weapons                                                                      29
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.countplot(x='Weapon_type', data=df, palette='inferno', order=df['Weapon_type'].value_counts().index)
_ = plt.xlabel('Weapon Used')
_ = plt.setp(ax.get_xticklabels(), rotation = 90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar graph is used to compare the items between different groups over time. Bar graphs are used to measure the changes over a period of time. When the changes are larger, a bar graph is the best option to represent the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we have already seen that bombing is the goto method for attacks explosives are 1st choice of weapon.Explosives and Firearms are largely used to execute terrorist activities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above insights will be helpful in proper vigilance over transboundary movement of weapons like Explosive and Firearms.Governments of affected countries can work together by sharing information of there borders for proper protection along borders.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# Specific Targets Of Terrorist Organizations

# %%
# Chart - 8 visualization code
df['Target_type'].value_counts()
# Out:
# Private Citizens & Property       42193
# Military                          26808
# Police                            24027
# Government (General)              20625
# Business                          20080
# Transportation                     6498
# Unknown                            5672
# Utilities                          5521
# Religious Figures/Institutions     4354
# Educational Institution            4234
# Government (Diplomatic)            3466
# Terrorists/Non-State Militia       2966
# Journalists & Media                2828
# Violent Political Party            1839
# Airports & Aircraft                1254
# Telecommunication                   989
# NGO                                 936
# Tourists                            417
# Maritime                            309
# Food or Water Supply                298
# Abortion Related                    260
# Other                               134
# Name: Target_type, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.countplot(x = 'Target_type', data=df, palette='icefire', order=df['Target_type'].value_counts().index)
_ = plt.xlabel('Targets of attack')
_ = plt.setp(ax.get_xticklabels(), rotation = 90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose countplot because
#
# 1.  It does not require too much effort to plot it.
# 2.  It is a widely used method of data representation.
#
# 1.   It is easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above figure we can see that private citizens and Military personals are mostly targeted and the top five targets are private citizens and property, military personals, police personals, government(general) officers.Personals who maintain law and order faced curse of terrorism at large.Common people are not exception they are mostly affected among all .security personals should be equipped more with all necessary weaponry for better protection of lives and propery

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insight will be helpful in effective deployments security forces

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
df['AttackType'].value_counts()
# Out:
# Bombing/Explosion                      86258
# Armed Assault                          40692
# Assassination                          18674
# Hostage Taking (Kidnapping)            10610
# Facility/Infrastructure Attack         10111
# Unknown                                 6875
# Unarmed Assault                          969
# Hostage Taking (Barricade Incident)      943
# Hijacking                                576
# Name: AttackType, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.countplot(x='AttackType', data=df, palette='plasma_r', order=df['AttackType'].value_counts().index)
_ = plt.xlabel('AttackType')
_ = plt.setp(ax.get_xticklabels(), rotation = 75)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1.   It represents the data in pictorial form.
# 2.  It makes the analysis of data easy.
#
# 1.   We can easily compare data with other variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the attacks are bombing/explosion as it has highest range among all options, with equally high damaging

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above data will be helpful in understanding motive and mean of terrorist activities deployed by terrorist groups

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# Variation of attack type with year

# %%
# Chart - 10 visualization code
terror_attack = pd.crosstab(df['Year'], df['AttackType'])
terror_attack.plot(color = sns.color_palette('Set3', 9))
fig = plt.gcf()
fig.set_size_inches(10, 6)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  key benefit of the crosstab function is that it allows you to normalize the resulting dataframe, returning values displayed as percentages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see from the above figure that bombing/explosion is the most used method for terror attacks over the years followed by armed assualt. Above analysis also shows that Bombings and Explosions were sharply increased for while since 2010.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above data will be helpful in understanding motive and mean of terrorist activities deployed by terrorist groups

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# Number of People Killed In Different AttackType

# %%
# Chart - 11 visualization code
attack_killed = df[['AttackType','Killed']].groupby(["AttackType"],axis=0).sum()
attack_killed
# Out:
#                                             Killed
# AttackType
# Armed Assault                        154968.891448
# Assassination                         23942.944934
# Bombing/Explosion                    166274.748546
# Facility/Infrastructure Attack         5280.047834
# Hijacking                              3638.492053
# Hostage Taking (Barricade Incident)    4717.176271
# Hostage Taking (Kidnapping)           31383.182823
# Unarmed Assault                         840.625461
# Unknown                               32213.129868

# %%
plt.subplots(figsize=(12,6))
sns.barplot(attack_killed.index, attack_killed.Killed.values,palette="cubehelix")
plt.title('Number of People Killed in each attack type')
plt.xlabel('Types ot attacks')
plt.ylabel('Number of people killed')
plt.xticks(rotation= 45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# 1.   Code complexity reduced.
# 2.   Much easier to shift reference frame of bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can see that in Armed Assualt,Assassination and Bombing/Explosion highest number of people were killed

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Above data will provide direction to understand possible cause of deaths in terrorist attack.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# Number of People Wounded In Different AttackType

# %%
# Chart - 12 visualization code
attack_wounded = df[['AttackType','Wounded']].groupby(["AttackType"],axis=0).sum()
attack_wounded
# Out:
#                                            Wounded
# AttackType
# Armed Assault                         86750.410768
# Assassination                         17729.181392
# Bombing/Explosion                    384066.699882
# Facility/Infrastructure Attack         5711.100489
# Hijacking                             16990.117514
# Hostage Taking (Barricade Incident)    4410.283992
# Hostage Taking (Kidnapping)           15627.083764
# Unarmed Assault                       14098.378230
# Unknown                               17226.479999

# %%
plt.subplots(figsize=(12,6))
sns.barplot(attack_wounded.index, attack_wounded.Wounded.values,palette="viridis")
plt.title('Number of People wounded in each attack type')
plt.xlabel('Types ot attacks')
plt.ylabel('Number of people wounded')
plt.xticks(rotation= 45)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# summarize a large dataset in visual form; easily compare two or three data sets; better clarify trends than do tables; estimate key values at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can see that the highest number of people were wounded by Bombing/Explosion

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As above analysis shows that Bombings and Explosions wounding large number of people so that steps can be taken by government agencies for proper vigilance of explosive devices.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# Most Active Terrorist Organization

# %%
# Chart - 13 visualization code
plt.subplots(figsize=(11,10))
sns.barplot(y=df['Group'].value_counts()[1:12].index,x=df['Group'].value_counts()[1:12].values,
           palette='copper')
plt.title('Most Active Terrorist Organizations')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we can easily represent our data on a plot. This library is used to visualize our data; we do not need to take care of the internal details; we just have to pass our data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above data analysis shows that Taliban is the most active terrorist organization followed by ISIL and SL.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Information of most active terrorist organizations can be helpful in restricting financial supports to them.Such datacan play a critical role in our fight against terrorism and are an effective means of curtailing support for terrorist activities .

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
plt.figure(figsize=(15,10))
#This shows how much related is one parameter to the other in the dataset.
#Heatmap shows correlation with numeric values
sns.heatmap(np.round(df.corr(),2),annot=True, cmap='BuPu')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap style correlation matrix is a very effective tool when used properly. The user will be able to identify highly correlated variables and this will allow them to streamline the feature selection process

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above data analysis shows that there is strong relationship between data of Wounded and Killed people in terrorist attacks.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
sns.pairplot(data,vars=["Wounded","Year","Killed","Month","Day"])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Seaborn Pairplot allows us to plot pairwise relationships between variables within a dataset. This creates a nice visualisation and helps us understand the data by summarising a large amount of data in a single figure.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Above plot shows that most of the killings were executed on middle of the month and at the end of month less killings were executed. Latitudinal and Longitudinal variations are clearly seen as most of the killing are recorded at the middle of latitude.Data shows killings were increased after 2000 till 2013 then started decreasing. In this whole pair plot, the importance of area code can be seen and the number of churn with respect to different features are really insightful. Rest insights can be depicted from the above graph.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Measures to be Taken to Reduce Terrorism
#
#
# 1.  Control access to dangerous weapons
# 2.   Government should provide more security over countries

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. Iraq has the most attacks.
# 2. The Middle East and North Africa Regions has most taregeted.
#
# 1.  Maximum number of attacks are from Bombing/Explosions.
# 2.  There are maximum number of attacks in Private citizens and Property.
#
# Above analysis encourage to take following steps
#
#
#
# *  Security should be strengthened across borders
# *  Government should take measures on increased immigration
# and many more…

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
